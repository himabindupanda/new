# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#1
foods = {'Pizza': 250, 'Burger': 150, 'Maggie': 200}
print(foods)
# Out:
# {'Pizza': 250, 'Burger': 150, 'Maggie': 200}

# %%
# 2
data=input()
a=data.split()
subject=a[0::2]
marks=map(int,a[1::2])
final=zip(subject,marks)
print(dict(final))
# Out:
#  maths 99 physics 89 science 98
# {'maths': 99, 'physics': 89, 'science': 98}

# %%
# 3
student = {'name': 'John', 'age': 18, 'grade': 'A'}
student['city'] = 'New York'
print(student)
# Out:
# {'name': 'John', 'age': 18, 'grade': 'A', 'city': 'New York'}

# %%
# 4
d1 = {'a': 1, 'b': 2}
d2 = {'b': 3, 'c': 4}
d1.update(d2)
print(d1)
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %%
# 5
person_a = {'Python': 'Advanced', 'Java': 'Intermediate'}
person_b = {'C++': 'Beginner', 'SQL': 'Intermediate'}
combined = {**person_a, **person_b}
print(combined)
# Out:
# {'Python': 'Advanced', 'Java': 'Intermediate', 'C++': 'Beginner', 'SQL': 'Intermediate'}

# %%
# 6
fruits = {'apple': 5, 'banana': 3, 'orange': 8}
print(fruits.keys())
# Out:
# dict_keys(['apple', 'banana', 'orange'])

# %%
# 7
colors = {'red': '#FF0000', 'green': '#00FF00', 'blue': '#0000FF'}
print(colors.values())
# Out:
# dict_values(['#FF0000', '#00FF00', '#0000FF'])

# %%
# 8
items = {'pen': 2, 'pencil': 5, 'eraser': 1}
removed = items.pop('pencil')
print("Removed:", removed)
print("Updated:", items)
# Out:
# Removed: 5
# Updated: {'pen': 2, 'eraser': 1}

# %%
# 9
stationery = {'pen': 2, 'eraser': 1}
print(stationery.get('marker'))
# Out:
# None

# %%
# 10
cars = {'Toyota': 2018, 'Ford': 2020, 'BMW': 2022}
removed = cars.popitem()
print("Removed:", removed)
# Out:
# Removed: ('BMW', 2022)

# %%
# 11
books = {'Book1': 'Author1', 'Book2': 'Author2'}
books.clear()
print(books)
# Out:
# {}

# %%
# 12
tools = {'hammer': 1, 'screwdriver': 2}
del tools
print(tools)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_35/3324331615.py in <cell line: 0>()
#       2 tools = {'hammer': 1, 'screwdriver': 2}
#       3 del tools
# ----> 4 print(tools)
#
# NameError: name 'tools' is not defined

# %%
# 13
keys = ['name', 'age', 'city']
values = ['John', 25, 'NYC']
person = dict(zip(keys, values))
print(person)
# Out:
# {'name': 'John', 'age': 25, 'city': 'NYC'}

# %%
# 14

words = input("Enter 5 words separated by space: ").split()
freq = {
    words[0]: words.count(words[0]),
    words[1]: words.count(words[1]),
    words[2]: words.count(words[2]),
    words[3]: words.count(words[3]),
    words[4]: words.count(words[4]),
}

print("Word Frequency Dictionary:", freq)
# Out:
# Enter 5 words separated by space:  bindu ram babbu charan bidya
# Word Frequency Dictionary: {'bindu': 1, 'ram': 1, 'babbu': 1, 'charan': 1, 'bidya': 1}

# %%
# 15
d = {'x': 10, 'y': 20, 'z': 30}
Above_15 = dict([('y', d['y']), ('z', d['z'])])
print("New Dictionary:", Above_15)
# Out:
# New Dictionary: {'y': 20, 'z': 30}

# %%
# 16
movies = {'darling': 2010, 'mr.perfect': 2012, 'bahubali': 2019}
print("Number of movies:", len(movies))
# Out:
# Number of movies: 3

# %%
# 17
langs = {'java': 1995, 'python': 1991, 'c++': 1985}
print('python' in langs)
# Out:
# True

# %%
# 18
student = {
    'personal': {'name': 'Alice', 'age': 17},
    'grades': {'math': 95, 'science': 90}
}
print(student['grades']['math'])
# Out:
# 95

# %%
# 19
s = 'hello'
ascii_dict = {char: ord(char) for char in s}
print(ascii_dict)
# Out:
# {'h': 104, 'e': 101, 'l': 108, 'o': 111}

# %%
# 20

A = {'a': 1, 'b': 2}
copy_A = A.copy()
copy_A['a'] = 100
print("Original:", A)
print("Copy:", copy_A)
# Out:
# Original: {'a': 1, 'b': 2}
# Copy: {'a': 100, 'b': 2}
