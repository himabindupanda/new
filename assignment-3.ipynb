# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#1
set1={'python','java','c'}
print(set1)
# Out:
# {'c', 'python', 'java'}

# %%
#2
hobbies=input()
hobby=set(hobbies.split())
print(hobby)
# Out:
#  dancing sleeping eating
# {'dancing', 'eating', 'sleeping'}

# %%
#3
colors = {'red', 'blue', 'green'}
colors.add('yellow')
print( colors)
# Out:
# {'yellow', 'blue', 'green', 'red'}

# %%
#4
set1 = {'apple', 'banana'}
set2 = {'banana', 'cherry'}
set1.update(set2)
print( set1)
# Out:
# {'banana', 'cherry', 'apple'}

# %%
#5
perA={'vizag','puri','hyd'}
perB={'hyd','sklm','tirupati'}
union=perA|perB
print(union)
# Out:
# {'vizag', 'sklm', 'tirupati', 'puri', 'hyd'}

# %%
#6
sset1={'alex','john','mike'}
sset2={'john','mike','lisa'}
inter=sset1 & sset2
print(inter)
# Out:
# {'mike', 'john'}

# %%
#7
items={'pen','pencil','eraser'}
items.discard('pencil')
print(items)
# Out:
# {'eraser', 'pen'}

# %%
#8
items={'pen','pencil','eraser'}
items.remove('marker')
print(items)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_35/3343722579.py in <cell line: 0>()
#       1 #8
#       2 items={'pen','pencil','eraser'}
# ----> 3 items.remove('marker')
#       4 print(items)
#
# KeyError: 'marker'

# %%
#9
set2={'mon','tue','wed','thurs','fri','sat'}
print(set2.pop())
print(set2)
# Out:
# wed
# {'sat', 'mon', 'thurs', 'tue', 'fri'}

# %%
#10
cars={'audi','toyoto','swift'}
cars.clear()
print(cars)
# Out:
# set()

# %%
#11
tools = {'Hammer', 'Wrench', 'Screwdriver'}
del tools
print(tools)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_35/97770252.py in <cell line: 0>()
#       2 tools = {'Hammer', 'Wrench', 'Screwdriver'}
#       3 del tools
# ----> 4 print(tools)
#
# NameError: name 'tools' is not defined

# %%
#12
set4 = set('hello')
print(set4)
# Out:
# {'h', 'o', 'l', 'e'}

# %%
#13
words = input().split()
unique_words = set(words)
print(unique_words)
# Out:
#  bindu rk ram bindu babbu ram
# {'ram', 'rk', 'babbu', 'bindu'}

# %%
#14
A = {'a', 'b', 'c'}
B = {'c', 'd', 'e'}
print( A - B)
# Out:
# {'a', 'b'}

# %%
#15
items2 = {'bed', 'chair', 'lamp'}
items2.add('bookshelf')
print(len(items2))
# Out:
# 4
